# %%
import sys, numpy as np
sys.path.append('../')
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Cold Dark Matter Baseline Tests

# %%
euler = -26.14186
indiv_silh_1 = -17.15937  
indiv_silh_2 = -7.790842
indiv_silh_3 = -0.2590126
all_silh = -15.19706
distr_1 = -0.9952205 
distr_2 = -1.4417 
distr_3 = -1.272205
contour_1 = -3.7297014 
contour_2 = -2.4079456 
contour_3 = -2.430418
global_1 = -0.8822320 
global_2 = -0.7876049 
global_3 = -0.7023436

bar_width = 0.7
plt.figure(figsize=(20,5))
total = [euler, indiv_silh_1, indiv_silh_2, indiv_silh_3, all_silh, distr_1, distr_2, distr_3, contour_1, contour_2, contour_3, global_1, global_2, global_3]
plt.bar(range(len(total)), np.exp(total), bar_width, alpha=0.6, color='r')
plt.ylabel("Probability")
plt.title("Hypothesis Testing Frameworks with Cold Dark Matter Baseline (Unnormalized)")
plt.xticks(np.arange(len(total)) + bar_width/2, ('euler', 'indiv_silh_1', 'indiv_silh_2', 'indiv_silh_3', 'all_silh', 'distr_1', 'distr_2', 'distr_3', 'contour_1', 'contour_2', 'contour_3', 'global_1', 'global_2', 'global_3'))
plt.savefig("../saved_states/cold_base_unnorm.pdf")
plt.savefig("../saved_states/cold_base_unnorm.png")
plt.show()

# %%
euler = -26.14186
indiv_silh_1 = -17.15937  
indiv_silh_2 = -7.790842
indiv_silh_3 = -0.2590126
all_silh = -15.19706
distr_1 = -0.9952205 
distr_2 = -1.4417 
distr_3 = -1.272205
contour_1 = -3.4420194  
contour_2 = -2.7181005 
contour_3 = -2.4534080
global_1 = -0.8822320 
global_2 = -0.7876049 
global_3 = -0.7023436

bar_width = 0.7
plt.figure(figsize=(20,5))
total = [euler, indiv_silh_1, indiv_silh_2, indiv_silh_3, all_silh, distr_1, distr_2, distr_3, contour_1, contour_2, contour_3, global_1, global_2, global_3]
plt.bar(range(len(total)), np.exp(total), bar_width, alpha=0.6, color='b')
plt.ylabel("Probability")
plt.title("Hypothesis Testing Frameworks with Warm Dark Matter Baseline (Unnormalized)")
plt.xticks(np.arange(len(total)) + bar_width/2, ('euler', 'indiv_silh_1', 'indiv_silh_2', 'indiv_silh_3', 'all_silh', 'distr_1', 'distr_2', 'distr_3', 'contour_1', 'contour_2', 'contour_3', 'global_1', 'global_2', 'global_3'))
plt.savefig("../saved_states/warm_base_unnorm.pdf")
plt.savefig("../saved_states/warm_base_unnorm.png")
plt.show()

# %%
euler = -14.19302
indiv_silh_1 = -1.481107 
indiv_silh_2 = -0.5755777 
indiv_silh_3 = -1.771103
all_silh = -1.151928
distr_1 = -2.410096 
distr_2 = -1.01605 
distr_3 = -0.8914756
contour_1 = -0.3681693    
contour_2 = 0 
contour_3 = -0.04082199 
global_1 = -0.7984966 
global_2 = -0.6987211 
global_3 = -0.6634393

bar_width = 0.7
plt.figure(figsize=(20,5))
total = [euler, indiv_silh_1, indiv_silh_2, indiv_silh_3, all_silh, distr_1, distr_2, distr_3, contour_1, contour_2, contour_3, global_1, global_2, global_3]
plt.bar(range(len(total)), np.exp(total), bar_width, alpha=0.6, color='purple')
plt.ylabel("Probability")
plt.title("Hypothesis Testing Frameworks with Cold Dark Matter Baseline (Normalized)")
plt.xticks(np.arange(len(total)) + bar_width/2, ('euler', 'indiv_silh_1', 'indiv_silh_2', 'indiv_silh_3', 'all_silh', 'distr_1', 'distr_2', 'distr_3', 'contour_1', 'contour_2', 'contour_3', 'global_1', 'global_2', 'global_3'))
plt.savefig("../saved_states/cold_base_norm.pdf")
plt.savefig("../saved_states/cold_base_norm.png")
plt.show()

# %%
euler = -14.19302
indiv_silh_1 = -1.481107 
indiv_silh_2 = -0.5755777 
indiv_silh_3 = -1.771103
all_silh = -1.151928
distr_1 = -2.410096 
distr_2 = -1.01605 
distr_3 = -0.8914756
contour_1 = -0.3312857 
contour_2 = 0 
contour_3 = -0.03666398
global_1 = -0.7984966
global_2 = -0.6987211 
global_3 = -0.6634393

bar_width = 0.7
plt.figure(figsize=(20,5))
total = [euler, indiv_silh_1, indiv_silh_2, indiv_silh_3, all_silh, distr_1, distr_2, distr_3, contour_1, contour_2, contour_3, global_1, global_2, global_3]
plt.bar(range(len(total)), np.exp(total), bar_width, alpha=0.6, color='orange')
plt.ylabel("Probability")
plt.title("Hypothesis Testing Frameworks with Warm Dark Matter Baseline (Normalized)")
plt.xticks(np.arange(len(total)) + bar_width/2, ('euler', 'indiv_silh_1', 'indiv_silh_2', 'indiv_silh_3', 'all_silh', 'distr_1', 'distr_2', 'distr_3', 'contour_1', 'contour_2', 'contour_3', 'global_1', 'global_2', 'global_3'))
plt.savefig("../saved_states/warm_base_norm.pdf")
plt.savefig("../saved_states/warm_base_norm.png")
plt.show()
