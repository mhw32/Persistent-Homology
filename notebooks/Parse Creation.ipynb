# %%
import sys, numpy as np
sys.path.append('../')
import parse
reload(parse)
# %matplotlib inline

# %%
start = '../saved_states/third_push/results-' 
end   = '-0.9base.txt'
filepaths = [start+str(i)+end for i in range(1, 21)]

# %%
resArr = np.array([parse.parse(f) for f in filepaths])

# %%
singles = ['all-silh', 'euler']
doubles = ['indiv_silh', 'distr', 'contour', 'global-kde']

# %%
for characteristic in singles:
    tmp = parse.prepare1d(resArr, characteristic)
    parse.plottest(np.exp(tmp), characteristic, save=True)

# %%
for characteristic in doubles:
    for dim in [0,1,2]:
        tmp = parse.prepare2d(resArr, characteristic, dim)
        parse.plottest(np.exp(tmp), characteristic + '-dim-' + str(dim), save=True)
