# %% [markdown]
# ### A test to see if resolution matters for the global kde test.

# %% [markdown]
# Fixed 3 cubic slicing + 2 different resolutinos.

# %%
res1 = [0.6185395902035, 0.708168683397229, 0.732460098942677, 0.149700494145247, 0.726274847437762, 0.252282366198442, 0.180612330512638, 0.19979365542944, 0.266403473305941, 0.941139303363801, 0.415853406722772, 0.158962673516282, 0.243838984755293, 0.48506298329023, 0.223206547304797, 0.46277703205803, 0.362289778481627, 0.835748412096773, 0.157016515624938, 0.816262452512575, 0.398191487242317, 0.757868729103447, 0.802227311153379, 0.574943114097831, 0.678140066231558, 0.620508636186714, 0.912824666734801]
res05 = [0.0291052618500615, 0.0377147273255298, 0.135591235845173, 0.249461105715306, 0.398367320866389, 0.160706263516897, 0.260181795604687, 0.412940818138419, 0.000611058292505517, 0.270511173273678, 0.326318522093002, 0.0438493688568593, 0.24733933028565, 0.164257000632107, 0.405480615065998, 0.214202879908122, 0.868696119429072, 0.22728518879685, 0.248055658290453, 0.285736484967535, 0.476587149079415, 0.0300387959737978, 0.113011944869573, 0.347221990868321, 0.118181426537543, 0.289918057234659, 0.28367648818218]
res025 = [0.123154256251433, 0.077299615948517, 0.00993615338901732, 0.206270261398952, 0.0862852193963717, 0.00557073669129515, 0.0282228149947309, 0.627677976807697, 0.000598863041877506,  0.152433304889322,  0.188815295635401,  0.0616231270467457,  0.00147104025105382,  0.480581101807768,  0.638125972059724,  0.493869166407867,  0.450585789426413,  0.0969532604642118,  0.138023136795987,  0.113561024339634,  0.46985661009086,  0.178635836446679,  0.259833143454853,  0.177703001855763,  0.203852570787113,  0.443969772102361,  0.378581467636135]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
xaxis = range(1, 28)
import matplotlib

# %%
plt.figure(figsize=[15,6])
matplotlib.rc('xtick', labelsize=18) 
matplotlib.rc('ytick', labelsize=18)
plotres1, = plt.plot(xaxis, res1, 'o', color='r', label="res:1")
plotres05, = plt.plot(xaxis, res05, 'o', color='g', label="res:0.5")
plotres025, = plt.plot(xaxis, res025, 'o', color='b', label="res:0.25")
plt.plot(xaxis, res05, '-', color='g', alpha=0.2)
plt.plot(xaxis, res1, '-', color='r', alpha=0.2)
plt.plot(xaxis, res025, '-', color='b', alpha=0.2)
plt.xlabel("Cube Index (Out of 27)", fontsize=20)
plt.ylabel("1-to-1 global KDE p-value", fontsize=20)
plt.title("Measure of effects of varying resolution on hypothesis testing frameworks", fontsize=20)
plt.legend([plotres1, plotres05, plotres025], fontsize=16, loc=2)
plt.savefig("../../Cisewski-Lab/saved_states/1_30_16//cube.pdf")
plt.show()
